# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnyanchal12345-sketch/ANCHAL/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pallidrom

# %%
lst =[1,2,3,'hello','c',[2,4]]
print(lst)


#append()
lst.append([2,3,4])
print(lst)

#extend()
lst.extend([2,3,4])
print(lst)


#insert()

lst.insert(2,"value")
print(lst)


#pop()
lst.pop()
print(lst)


#remove()

lst.remove(2)
print(lst)

#index()
lst.index(3)
print(lst.index(2))


#count()

print(lst.count(4))

#sort()

lst=[1,3,0,-1]
lst.sort()
print(lst)
# Out:
# [1, 2, 3, 'hello', 'c', [2, 4]]
# [1, 2, 3, 'hello', 'c', [2, 4], [2, 3, 4]]
# [1, 2, 3, 'hello', 'c', [2, 4], [2, 3, 4], 2, 3, 4]
# [1, 2, 'value', 3, 'hello', 'c', [2, 4], [2, 3, 4], 2, 3, 4]
# [1, 2, 'value', 3, 'hello', 'c', [2, 4], [2, 3, 4], 2, 3]
# [1, 'value', 3, 'hello', 'c', [2, 4], [2, 3, 4], 2, 3]
# 7
# 0
# [-1, 0, 1, 3]

# %%
lst=['anchal',17.5,]
print(lst)

#append()
lst.append([4,9])
print(lst)

#extend()
lst.extend([3,5])
print(lst)

#insert()
lst.insert(17,"anchal")
print(lst)

#pop

lst.remove(17.5)
print(lst)
# Out:
# ['anchal', 17.5]
# ['anchal', 17.5, [4, 9]]
# ['anchal', 17.5, [4, 9], 3, 5]
# ['anchal', 17.5, [4, 9], 3, 5, 'anchal']
# ['anchal', [4, 9], 3, 5, 'anchal']

# %%
lst=(1,3,0,-1)
a = sum(lst)
print(a)


#min
lst=(1,3,0,-1)





#max







#sorted
lst= (1,3,0,-1)
sorted(lst)
print(lst)
# Out:
# 3
# (1, 3, 0, -1)

# %%
tp=(1,2,33,4)
a=tuple(sorted(tp))
print(a)
# Out:
# (1, 2, 4, 33)

# %%
#tuples function

#category function
#count values
#find
#size
#total
#highest/lowest
#sort


#string
#count()
#index()
#len()
#sum()
#max() min()
#sorted() (return list)

# %%
tp=(23,4,7,84)
a=tp.count(4)
print(a)
# Out:
# 1

# %%
lst1=[2,3,4,5,9]
lst2=[1,0,3,1,2]
size=int(input())

for i in range (size):
    x=int(input())

    lst1.append(x)


for j in range(size):
  y=int(input())

  lst2.append(y)

lst3=[]
9for i in range(size):
    lst3.append(lst1[i]+lst2[i])
print(lst3)
# Out:
# 5
# 1
# 2
# 7
# 9
# 44
# 1
# 28
# 9
# 11
# 6
# [3, 3, 7, 6, 11]
